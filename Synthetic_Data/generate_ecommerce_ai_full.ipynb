# %% [markdown]
# # E-commerce Synthetic Dataset (AI Complete)
# Generate a fully synthetic e-commerce dataset and save it as `ecommerce_ai_complete.csv`.

# %%
from pathlib import Path

from generate_ecommerce_ai_full import make_ai_complete_ecommerce

# %%
output_path = Path('ecommerce_ai_complete.csv')
df = make_ai_complete_ecommerce(n_rows=9000)
df.to_csv(output_path, index=False)

print(f'Saved {output_path} with {len(df)} rows')
print('Shape:', df.shape)
df.head()
# Out:
# Saved ecommerce_ai_complete.csv with 9000 rows
# Shape: (9000, 8)
#   InvoiceNo StockCode                        Description  Quantity  \
# 0    587958    F99833           REGENCY CAKESTAND 3 TIER         7
# 1    645677    B14236               FELTCRAFT DOLL ROSIE         5
# 2    678371    B94343  WOODEN PICTURE FRAME WHITE FINISH        11
# 3    582189    D86644   SET OF 3 CAKE TINS PANTRY DESIGN         5
# 4    625885    E42734   SET OF 3 CAKE TINS PANTRY DESIGN         8
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2024-12-05 09:36:00      11.08     14831.0  United Kingdom
# 1 2024-11-19 19:50:00       3.77     13900.0  United Kingdom
# 2 2024-07-10 15:03:00       6.36     15231.0  United Kingdom
# 3 2024-05-13 22:21:00       9.38     16783.0  United Kingdom
# 4 2024-10-11 04:15:00      14.02     17596.0  United Kingdom
