# %% [markdown]
# # E-commerce Synthetic Dataset (Python Script)
# Generate the Python-script-based e-commerce synthetic dataset and save it as `ecommerce_python_script.csv`.

# %%
from pathlib import Path

import numpy as np
import pandas as pd

from generate_synthetic_datasets import make_ecommerce_dataset

# %%
output_path = Path('ecommerce_python_script.csv')
rows = int(np.random.randint(6200, 9100))
df = make_ecommerce_dataset(rows)
df.to_csv(output_path, index=False)

print(f'Saved {output_path} with {len(df)} rows')
print('Shape:', df.shape)
df.head()
# Out:
# Saved ecommerce_python_script.csv with 7060 rows
# Shape: (7060, 15)
#        customer_id   customer_name   age  gender      city  country  \
# 0  CUST-0D06D1A5BE    Zachary Boyd  55.0  Female  New York      NaN
# 1  CUST-A53FAAA163      Jean Smith  51.0    Male    London       UK
# 2  CUST-880FF0F7E8     Monica Long  30.0  Female   Chicago      NaN
# 3  CUST-1D9084282C    James Tucker  35.0  Female     Paris   France
# 4  CUST-0FEBE8B96E  Emma Rodriguez  30.0  Female    Munich  Germany
#
#           signup_date  last_purchase_date  total_orders  avg_order_value  \
# 0 2021-03-02 04:01:40 2023-01-14 04:01:40           3.0           175.47
# 1 2025-01-03 21:16:19                 NaT           2.0            66.58
# 2 2026-02-27 20:27:51 2026-03-03 20:27:51           2.0           149.99
# 3 2022-05-26 07:44:06 2022-11-08 07:44:06           7.0           152.47
# 4 2019-11-07 23:31:55 2021-02-21 23:31:55           4.0           144.46
#
# ...
